# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd

# %% [markdown]
# ## Red Wine

# %% [markdown]
# **Import Red Wine CSV File and Convert to Pandas DataFrame**

# %%
red_wine_csv = 'Resources/winequality-red.csv'
red_wine_df = pd.read_csv(red_wine_csv, sep = ';')
red_wine_df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1069            8.0              0.62         0.35             2.8      0.086
# 182             7.2              0.73         0.02             2.5      0.076
# 291            11.0              0.20         0.48             2.0      0.343
# 967             8.5              0.66         0.20             2.1      0.097
# 1387            7.4              0.64         0.07             1.8      0.100
# 1569            6.2              0.51         0.14             1.9      0.056
# 418            11.9              0.38         0.51             2.0      0.121
# 672             9.8              1.24         0.34             2.0      0.079
# 475             9.6              0.68         0.24             2.2      0.087
# 560            12.7              0.60         0.49             2.8      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# **Check Datatypes**

# %%
red_wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# **Check For Missing Rows of Data**

# %%
red_wine_df.notnull().count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %% [markdown]
# **Add Wine Color Column**

# %%
red_wine_df['wine color'] = 'red'
red_wine_df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 600             8.2             0.915         0.27             2.1      0.088
# 391            13.7             0.415         0.68             2.9      0.085
# 199             6.9             1.090         0.06             2.1      0.061
# 627             8.8             0.600         0.29             2.2      0.098
# 143             6.3             0.390         0.08             1.7      0.066
# 479             9.4             0.685         0.11             2.7      0.077
# 1440            7.2             0.370         0.32             2.0      0.062
# 813             6.9             0.390         0.24             2.1      0.102
# 1543           11.1             0.440         0.42             2.2      0.064
# 423            10.5             0.240         0.47             2.1      0.066
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## White Wine

# %% [markdown]
# **Import Red Wine CSV File and Convert to Pandas DataFrame**

# %%
white_wine_csv = 'Resources/winequality-white.csv'
white_wine_df = pd.read_csv(white_wine_csv, sep = ';')
white_wine_df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4672            4.9             0.335         0.14            1.30      0.036
# 2223            6.9             0.230         0.33           12.80      0.056
# 435             6.9             0.200         0.37            6.20      0.027
# 3393            8.0             0.280         0.30            8.40      0.030
# 4054            7.2             0.170         0.28           17.55      0.050
# 3557            8.1             0.200         0.28            0.90      0.023
# 1479            7.7             0.160         0.49            2.00      0.056
# 1563            7.8             0.300         0.74            1.80      0.033
# 133             6.6             0.240         0.27           15.80      0.035
# 2795            6.4             0.220         0.32            7.20      0.028
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# **Check Datatypes**

# %%
white_wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# **Check For Missing Rows of Data**

# %%
white_wine_df.notnull().count()
# Out:
# fixed acidity           4898
# volatile acidity        4898
# citric acid             4898
# residual sugar          4898
# chlorides               4898
# free sulfur dioxide     4898
# total sulfur dioxide    4898
# density                 4898
# pH                      4898
# sulphates               4898
# alcohol                 4898
# quality                 4898
# dtype: int64

# %% [markdown]
# **Add Wine Color Column**

# %%
white_wine_df['wine color'] = 'white'
white_wine_df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3728            6.2             0.200         0.33            5.40      0.028
# 2473            6.0             0.290         0.21           15.55      0.043
# 2499            6.9             0.260         0.31            7.00      0.039
# 2668            9.6             0.655         0.21            2.00      0.039
# 289             7.2             0.230         0.39           14.20      0.058
# 3608            7.0             0.160         0.25           14.30      0.044
# 173             6.3             0.220         0.43            4.55      0.038
# 4542            6.9             0.280         0.37            9.10      0.037
# 2196            7.0             0.220         0.26            1.10      0.037
# 1344            7.3             0.230         0.37            1.90      0.041
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## Con Red and White Wine DataFrames

# %%
wine_df = pd.concat([red_wine_df, white_wine_df], ignore_index = True)
wine_df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6223            6.4              0.40         0.25             4.2      0.032
# 3712            5.7              0.33         0.15             1.9      0.050
# 2930            6.8              0.15         0.32             8.8      0.058
# 1176            6.5              0.88         0.03             5.6      0.079
# 3441            8.2              0.18         0.31            11.8      0.039
# 4627            7.5              0.18         0.37             6.2      0.050
# 5576            6.9              0.27         0.25             7.5      0.030
# 6088            6.7              0.48         0.49             2.9      0.030
# 1662            6.6              0.38         0.15             4.6      0.044
# 1571            6.4              0.38         0.14             2.2      0.038
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...
